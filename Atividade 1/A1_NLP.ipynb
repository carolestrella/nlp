# %%
import re

# %%
import pandas as pd

# %%
file = pd.read_csv("https://raw.githubusercontent.com/viniciusrpb/cic0269_natural_language_processing/main/diario_oficial_pref_sp/dosp_29012016.csv")

# %%
file
# Out:
#                  ID                  Data Retranca Tipo do Conteúdo  \
# 0      2016/01/29/0  2016-01-29T00:00:00Z  efmaadm       LICITAÇÕES
# 1      2016/01/29/1  2016-01-29T00:00:00Z  efaaadm       LICITAÇÕES
# 2      2016/01/29/2  2016-01-29T00:00:00Z  efmaadm       LICITAÇÕES
# 3      2016/01/29/3  2016-01-29T00:00:00Z  epaaadm       LICITAÇÕES
# 4      2016/01/29/4  2016-01-29T00:00:00Z  epwbadm       LICITAÇÕES
# ..              ...                   ...      ...              ...
# 701  2016/01/29/702  2016-01-29T00:00:00Z  dseaadm          EDITAIS
# 702  2016/01/29/703  2016-01-29T00:00:00Z  bpaaadm       SERVIDORES
# 703  2016/01/29/704  2016-01-29T00:00:00Z  bofaadm       SERVIDORES
# 704  2016/01/29/705  2016-01-29T00:00:00Z  abnxidm         DESPACHO
# 705  2016/01/29/706  2016-01-29T00:00:00Z  agidadm         DESPACHO
#
#                          Secretaria  \
# 0                                 -
# 1                           CULTURA
# 2                                 -
# 3                             SAÚDE
# 4    AUTARQUIA HOSPITALAR MUNICIPAL
# ..                              ...
# 701                     TRANSPORTES
# 702                           SAÚDE
# 703          DESENVOLVIMENTO URBANO
# 704    DIREITOS HUMANOS E CIDADANIA
# 705                        EDUCAÇÃO
#
#                                           Orgão  \
# 0                                             -
# 1                        GABINETE DO SECRETÁRIO
# 2                                             -
# 3                        GABINETE DO SECRETÁRIO
# 4                DIRETORIA DE GESTÃO DE PESSOAL
# ..                                          ...
# 701               DEPTO DE TRANSPORTES PÚBLICOS
# 702                      GABINETE DO SECRETÁRIO
# 703                      GABINETE DO SECRETÁRIO
# 704                      GABINETE DO SECRETÁRIO
# 705  DIRETORIA REGIONAL DE EDUCAÇÃO DE PIRITUBA
#
#                                                  Texto Unnamed: 7 Unnamed: 8  \
# 0    ((TITULO))Extrato de Termo de Aditamento\n((TE...        NaN        NaN
# 1    ((TITULO))CONTRAÇÃO DE NATUREZA ARTÍSTICA\n\n(...        NaN        NaN
# 2    ((TITULO))Extrato de Termo de Aditamento\n((TE...        NaN        NaN
# 3    ((TITULO))PROCESSO: 2015-0.272.291-3\n((TEXTO)...        NaN        NaN
# 4    ((TITULO))PENALIDADE\n((TEXTO))((NG))PROCESSO ...        NaN        NaN
# ..                                                 ...        ...        ...
# 701  ((TEXTO))((NG))INTIMAÇÃO((CL))\nProcesso Admin...        NaN        NaN
# 702  ((TITULO))COORDENAÇÃO DE GESTÃO DE PESSOAS - C...        NaN        NaN
# 703  ((TITULO))LICENÇA MÉDICA - RGPS\n((TEXTO))Conc...        NaN        NaN
# 704  ((TITULO))Processo Eletrônico nº 6074.2016/000...        NaN        NaN
# 705  ((TITULO))DIRETORIA REGIONAL DE EDUCAÇÃO - PIR...        NaN        NaN
#
#     Unnamed: 9 Unnamed: 10 Unnamed: 11 Unnamed: 12
# 0          NaN         NaN         NaN         NaN
# 1          NaN         NaN         NaN         NaN
# 2          NaN         NaN         NaN         NaN
# 3          NaN         NaN         NaN         NaN
# 4          NaN         NaN         NaN         NaN
# ..         ...         ...         ...         ...
# 701        NaN         NaN         NaN         NaN
# 702        NaN         NaN         NaN         NaN
# 703        NaN         NaN         NaN         NaN
# 704        NaN         NaN         NaN         NaN
# 705        NaN         NaN         NaN         NaN
#
# [706 rows x 13 columns]

# %%
t = file.iloc[:7,6]
t
# Out:
# 0    ((TITULO))Extrato de Termo de Aditamento\n((TE...
# 1    ((TITULO))CONTRAÇÃO DE NATUREZA ARTÍSTICA\n\n(...
# 2    ((TITULO))Extrato de Termo de Aditamento\n((TE...
# 3    ((TITULO))PROCESSO: 2015-0.272.291-3\n((TEXTO)...
# 4    ((TITULO))PENALIDADE\n((TEXTO))((NG))PROCESSO ...
# 5    ((TITULO))2015-0.038.991-5 \n((TEXTO))À vista ...
# 6    ((TITULO))DISPENSA DE LICITAÇÃO\n\n((TEXTO))((...
# Name: Texto, dtype: object

# %%
titles = []
processes = []
values = []

# %%
for line in t:
  title = re.findall(r"..TITULO..(.*)\s*..TEXTO..", line)
  print(title)
  titles.append(title[0])
# Out:
# ['Extrato de Termo de Aditamento']
# ['CONTRAÇÃO DE NATUREZA ARTÍSTICA']
# ['Extrato de Termo de Aditamento']
# ['PROCESSO: 2015-0.272.291-3']
# ['PENALIDADE']
# ['2015-0.038.991-5 ']
# ['DISPENSA DE LICITAÇÃO']

# %%
for line in t:
  process = re.findall(r".*.SEI(.*)..CL..", line)
  if(process == []):
    process.append("NaN")
  print(process)
  processes.append(process[0])
# Out:
# ['NaN']
# [' 6025.2016/0000082-0']
# ['NaN']
# ['NaN']
# ['NaN']
# ['NaN']
# [' 6025.2016/0000004-8']

# %%
for line in t:
  value = re.findall(r".*VALOR GLOBAL.*..CL....(..........)", line)
  if(value == []):
    value.append("NaN")
  print(value)
  values.append(value[0])
# Out:
# ['NaN']
# [' 14.000,00']
# ['NaN']
# ['NaN']
# ['NaN']
# ['NaN']
# ['NaN']

# %%
print(titles[0])
# Out:
# ['Extrato de Termo de Aditamento']

# %%
list = []

for i in range(t.size):
  list.append([titles[i], processes[i], values[i]])

# %%
df = pd.DataFrame(list, columns = ['Título', 'Número do Processo', 'Valor'])

# %%
df
# Out:
#                             Título    Número do Processo       Valor
# 0   Extrato de Termo de Aditamento                   NaN         NaN
# 1  CONTRAÇÃO DE NATUREZA ARTÍSTICA   6025.2016/0000082-0   14.000,00
# 2   Extrato de Termo de Aditamento                   NaN         NaN
# 3       PROCESSO: 2015-0.272.291-3                   NaN         NaN
# 4                       PENALIDADE                   NaN         NaN
# 5                2015-0.038.991-5                    NaN         NaN
# 6            DISPENSA DE LICITAÇÃO   6025.2016/0000004-8         NaN
